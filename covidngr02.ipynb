# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
covid_df = pd.read_excel('C:/Users/HP/Desktop/Paul Unilag Project/Nigeria Covid-19 Data Analysis Project/Nigeria Covid-19 Data Analysis Project_Statewise.xlsx')

# %%
covid_df.head(37)
# Out:
#     ID                 DATE  ISO_3  COUNTRY  ID_COUNTRY  \
# 0    1  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 1    2  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 2    3  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 3    4  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 4    5  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 5    6  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 6    7  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 7    8  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 8    9  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 9   10  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 10  11  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 11  12  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 12  13  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 13  14  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 14  15  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 15  16  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# ...

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ID                            37 non-null     int64
#  1   DATE                          37 non-null     object
#  2   ISO_3                         37 non-null     object
#  3   COUNTRY                       37 non-null     object
#  4   ID_COUNTRY                    37 non-null     int64
#  5   STATE                         37 non-null     object
#  6   ID_STATE                      37 non-null     int64
#  7   INFECTED                      37 non-null     int64
#  8   DEAD                          37 non-null     int64
#  9    HEALED                       37 non-null     int64
#  10  ACTIVE                        37 non-null     int64
#  11  INFECTED_NON_SPECIFIC_GENDER  37 non-null     int64
#  12  SOURCE                        37 non-null     object
# ...

# %%
covid_df.describe()
# Out:
#               ID  ID_COUNTRY    ID_STATE      INFECTED        DEAD  \
# count  37.000000        37.0   37.000000     37.000000   37.000000
# mean   19.000000        15.0  188.000000   6562.054054   84.729730
# std    10.824355         0.0   10.824355  16396.795180  134.458099
# min     1.000000        15.0  170.000000      0.000000    2.000000
# 25%    10.000000        15.0  179.000000   1203.000000   25.000000
# 50%    19.000000        15.0  188.000000   2399.000000   37.000000
# 75%    28.000000        15.0  197.000000   4919.000000   89.000000
# max    37.000000        15.0  206.000000  98366.000000  769.000000
#
#              HEALED        ACTIVE  INFECTED_NON_SPECIFIC_GENDER
# count     37.000000     37.000000                     37.000000
# mean    6189.702703    287.621622                   5181.864865
# std    13538.481038   3373.707459                  12978.938739
# min        3.000000 -10224.000000                      0.000000
# ...

# %%
region_df = pd.read_excel('C:/Users/HP/Desktop/Paul Unilag Project/Nigeria Covid-19 Data Analysis Project/Nigeria Covid-19 Data Analysis Project_Regions.xlsx')

# %%
region_df.head(7)
# Out:
#     ID                  DATE ISO_3  COUNTRY  ID_COUNTRY            REGION  \
# 0  1.0  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-WEST (SW)
# 1  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-EAST (SE)
# 2  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15  SOUTH-SOUTH (SS)
# 3  NaN  2/27/2020 - 2/2/2023   NGA  Nigéria          15   NORTH-WEST (NW)
# 4  NaN  2/27/2020 - 2/2/2024   NGA  Nigéria          15   NORTH-EAST (NE)
# 5  NaN  2/27/2020 - 2/2/2025   NGA  Nigéria          15       MIDDLE BELT
#
#    \nINFECTED  \nDEAD   \nHEALED  ACTIVE  \nINFECTED_NON_SPECIFIC_GENDER  \
# 0      129298    1343     109299   18656                           99426
# 1       12353     172      11972     209                            8229
# 2       36047     680      35127     240                           28194
# 3       20833     323      20383     127                           14981
# 4       10016     207       9531     278                            7234
# ...

# %%
region_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             1 non-null      float64
#  1   DATE                           6 non-null      object
#  2   ISO_3                          6 non-null      object
#  3   COUNTRY                        6 non-null      object
#  4   ID_COUNTRY                     6 non-null      int64
#  5   REGION                         6 non-null      object
#  6
# INFECTED                      6 non-null      int64
#  7
# DEAD                          6 non-null      int64
#  8
# HEALED                       6 non-null      int64
#  9   ACTIVE                         6 non-null      int64
#  10
# INFECTED_NON_SPECIFIC_GENDER  6 non-null      int64
#  11  ACTIVE.1                       6 non-null      int64
# ...

# %%
region_df.describe()
# Out:
#         ID  ID_COUNTRY     \nINFECTED       \nDEAD       \nHEALED  \
# count  1.0         6.0       6.000000     6.000000       6.000000
# mean   1.0        15.0   42913.500000   532.833333   38858.500000
# std    NaN         0.0   44831.719194   438.663159   37319.717983
# min    1.0        15.0   10016.000000   172.000000    9531.000000
# 25%    1.0        15.0   14473.000000   236.000000   14074.750000
# 50%    1.0        15.0   28440.000000   397.500000   27755.000000
# 75%    1.0        15.0   45712.250000   628.000000   43911.000000
# max    1.0        15.0  129298.000000  1343.000000  109299.000000
#
#              ACTIVE  \nINFECTED_NON_SPECIFIC_GENDER      ACTIVE.1
# count      6.000000                        6.000000      6.000000
# mean    3522.166667                    32536.666667   3522.166667
# std     7435.606375                    34795.600122   7435.606375
# min      127.000000                     7234.000000    127.000000
# ...

# %%
covid_df.head()
# Out:
#    ID                 DATE  ISO_3  COUNTRY  ID_COUNTRY      STATE  ID_STATE  \
# 0   1  2/27/2020 - 2/2/2022   NGA  Nigéria          15       Abia       170
# 1   2  2/27/2020 - 2/2/2022   NGA  Nigéria          15    Adamawa       171
# 2   3  2/27/2020 - 2/2/2022   NGA  Nigéria          15  Akwa Ibom       172
# 3   4  2/27/2020 - 2/2/2022   NGA  Nigéria          15    Anambra       173
# 4   5  2/27/2020 - 2/2/2022   NGA  Nigéria          15     Bauchi       174
#
#    INFECTED  DEAD   HEALED  ACTIVE  INFECTED_NON_SPECIFIC_GENDER  \
# 0      2152    34     2112       6                          1254
# 1      1203    32     1103      68                           955
# 2      4625    44     4494      87                          4330
# 3      2743    19     2678      46                          2468
# 4      1936    24     1878      34                          1226
#
#                                SOURCE
# 0  Nigeria Centre for Disease Control
# 1  Nigeria Centre for Disease Control
# ...

# %%
region_df.head(8)
# Out:
#     ID                  DATE ISO_3  COUNTRY  ID_COUNTRY            REGION  \
# 0  1.0  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-WEST (SW)
# 1  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-EAST (SE)
# 2  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15  SOUTH-SOUTH (SS)
# 3  NaN  2/27/2020 - 2/2/2023   NGA  Nigéria          15   NORTH-WEST (NW)
# 4  NaN  2/27/2020 - 2/2/2024   NGA  Nigéria          15   NORTH-EAST (NE)
# 5  NaN  2/27/2020 - 2/2/2025   NGA  Nigéria          15       MIDDLE BELT
#
#    \nINFECTED  \nDEAD   \nHEALED  ACTIVE  \nINFECTED_NON_SPECIFIC_GENDER  \
# 0      129298    1343     109299   18656                           99426
# 1       12353     172      11972     209                            8229
# 2       36047     680      35127     240                           28194
# 3       20833     323      20383     127                           14981
# 4       10016     207       9531     278                            7234
# ...

# %%
# Calculate Active Cases

covid_df['ACTIVE'] = covid_df['INFECTED'] - (covid_df[' HEALED'] + covid_df['DEAD'])
covid_df.tail()
# Out:
#     ID                 DATE  ISO_3  COUNTRY  ID_COUNTRY    STATE  ID_STATE  \
# 32  33  2/27/2020 - 2/2/2022   NGA  Nigéria          15   Rivers       202
# 33  34  2/27/2020 - 2/2/2022   NGA  Nigéria          15   Sokoto       203
# 34  35  2/27/2020 - 2/2/2022   NGA  Nigéria          15   Taraba       204
# 35  36  2/27/2020 - 2/2/2022   NGA  Nigéria          15     Yobe       205
# 36  37  2/27/2020 - 2/2/2022   NGA  Nigéria          15  Zamfara       206
#
#     INFECTED  DEAD   HEALED  ACTIVE  INFECTED_NON_SPECIFIC_GENDER  \
# 32     16422   154    16148     120                         13726
# 33       811    28      783       0                           649
# 34      1469    34     1377      58                          1352
# 35       509     9      490      10                           430
# 36       375     9      366       0                           296
#
#                                 SOURCE
# 32  Nigeria Centre for Disease Control
# ...

# %%
statewise = pd.pivot_table(covid_df, values = ["INFECTED"," HEALED", "DEAD"], index = "STATE", aggfunc = max)

# %%
statewise["Recovery Rate"] = statewise[" HEALED"]*100/statewise["INFECTED"]

# %%
statewise["Mortality Rate"] = statewise["DEAD"]*100/statewise["INFECTED"]

# %%
statewise = statewise.sort_values(by = "INFECTED", ascending = False)

# %%
statewise.style.background_gradient(cmap = "cubehelix")
# Out:
# c:\Python311\Lib\site-packages\pandas\io\formats\style.py:3622: RuntimeWarning: invalid value encountered in scalar multiply
#   norm = _matplotlib.colors.Normalize(smin - (rng * low), smax + (rng * high))
# <style type="text/css">
# #T_f3b03_row0_col0, #T_f3b03_row0_col1, #T_f3b03_row0_col2 {
#   background-color: #ffffff;
#   color: #000000;
# }
# ...

# %%
# Top 10 States with Highest Active Cases

top_10_states_active_cases = covid_df.groupby(by = ['STATE']).max()[['ACTIVE']], sort_values(by = ['ACTIVE'], ascending = False).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 3
#       1 # Top 10 States with Highest Active Cases
# ----> 3 top_10_states_active_cases = covid_df.groupby(by = ['STATE']).max()[['ACTIVE']], sort_values(by = ['ACTIVE'], ascending = False).reset_index()
#
# NameError: name 'sort_values' is not defined

# %%
covid_df_sorted = covid_df.sort_values('STATE')

# %%
# Top 10 States with Highest Active Cases

top_10_states_active_cases = covid_df.groupby(by = ['STATE']).max()[['ACTIVE']], sort_values(by = ['ACTIVE'], ascending = False).reset_index()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 3
#       1 # Top 10 States with Highest Active Cases
# ----> 3 top_10_states_active_cases = covid_df.groupby(by = ['STATE']).max()[['ACTIVE']], sort_values(by = ['ACTIVE'], ascending = False).reset_index()
#
# NameError: name 'sort_values' is not defined

# %%
# Top 10 States with Highest Active Cases

top_10_states_active_cases = covid_df.groupby(by = ['STATE']).max()[['ACTIVE']].reset_index()

# %%
fig = plt.figure(figsize=(16,9))

# %%
plt.title("Top 10 States in Nigeria with Most Active Covid-19 Cases", size = 25)
# Out:
# Text(0.5, 1.0, 'Top 10 States in Nigeria with Most Active Covid-19 Cases')

# %%
ax = sns.barplot(data = top_10_states_active_cases.iloc[:10], y ="ACTIVE", x = "STATE", linewidth = 2, edgecolor = 'green')

# %%
covid_df_sorted = covid_df.sort_values('STATE')
# Top 10 States with Highest Active Cases
top_10_states_active_cases = covid_df.groupby(by = ['STATE']).max()[['ACTIVE']].reset_index()
fig = plt.figure(figsize=(16,9))
plt.title("Top 10 States in Nigeria with Most Active Covid-19 Cases", size = 25)
ax = sns.barplot(data = top_10_states_active_cases.iloc[:10], y ="ACTIVE", x = "STATE", linewidth = 2, edgecolor = 'green')
plt.xlabel('STATE')
plt.ylabel('ACTIVE')
plt.show()

# %%
# States With Highest Deaths

top_10_deaths = covid_df.groupby(by = 'STATE').max()[['DEAD']].sort_values(by = ['DEAD'], ascending = False).reset_index()

fig = plt.figure(figsize=(18,7))

plt.title('Top 10 States with Most Recorded COVID-19 Deaths', size = 30)

ax = sns.barplot(data = top_10_deaths.iloc[:10], y = 'DEAD', x = 'STATE', linewidth = 2, edgecolor = 'blue')

plt.xlabel('STATE')
plt.ylabel('DEAD')
plt.show()

# %%
region_df.head()
# Out:
#     ID                  DATE ISO_3  COUNTRY  ID_COUNTRY            REGION  \
# 0  1.0  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-WEST (SW)
# 1  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-EAST (SE)
# 2  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15  SOUTH-SOUTH (SS)
# 3  NaN  2/27/2020 - 2/2/2023   NGA  Nigéria          15   NORTH-WEST (NW)
# 4  NaN  2/27/2020 - 2/2/2024   NGA  Nigéria          15   NORTH-EAST (NE)
#
#    \nINFECTED  \nDEAD   \nHEALED  ACTIVE  \nINFECTED_NON_SPECIFIC_GENDER  \
# 0      129298    1343     109299   18656                           99426
# 1       12353     172      11972     209                            8229
# 2       36047     680      35127     240                           28194
# 3       20833     323      20383     127                           14981
# 4       10016     207       9531     278                            7234
#
#    ACTIVE.1                              SOURCE
# ...

# %%
region_df.head()
# Out:
#     ID                  DATE ISO_3  COUNTRY  ID_COUNTRY            REGION  \
# 0  1.0  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-WEST (SW)
# 1  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-EAST (SE)
# 2  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15  SOUTH-SOUTH (SS)
# 3  NaN  2/27/2020 - 2/2/2023   NGA  Nigéria          15   NORTH-WEST (NW)
# 4  NaN  2/27/2020 - 2/2/2024   NGA  Nigéria          15   NORTH-EAST (NE)
#
#    \nINFECTED  \nDEAD   \nHEALED  ACTIVE  \nINFECTED_NON_SPECIFIC_GENDER  \
# 0      129298    1343     109299   18656                           99426
# 1       12353     172      11972     209                            8229
# 2       36047     680      35127     240                           28194
# 3       20833     323      20383     127                           14981
# 4       10016     207       9531     278                            7234
#
#    ACTIVE.1                              SOURCE
# ...

# %%
region_df.head()
# Out:
#     ID                  DATE ISO_3  COUNTRY  ID_COUNTRY            REGION  \
# 0  1.0  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-WEST (SW)
# 1  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-EAST (SE)
# 2  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15  SOUTH-SOUTH (SS)
# 3  NaN  2/27/2020 - 2/2/2023   NGA  Nigéria          15   NORTH-WEST (NW)
# 4  NaN  2/27/2020 - 2/2/2024   NGA  Nigéria          15   NORTH-EAST (NE)
#
#    \nINFECTED  \nDEAD   \nHEALED  ACTIVE  \nINFECTED_NON_SPECIFIC_GENDER  \
# 0      129298    1343     109299   18656                           99426
# 1       12353     172      11972     209                            8229
# 2       36047     680      35127     240                           28194
# 3       20833     323      20383     127                           14981
# 4       10016     207       9531     278                            7234
#
#    ACTIVE.1                              SOURCE
# ...

# %%
region_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             1 non-null      float64
#  1   DATE                           6 non-null      object
#  2   ISO_3                          6 non-null      object
#  3   COUNTRY                        6 non-null      object
#  4   ID_COUNTRY                     6 non-null      int64
#  5   REGION                         6 non-null      object
#  6
# INFECTED                      6 non-null      int64
#  7
# DEAD                          6 non-null      int64
#  8
# HEALED                       6 non-null      int64
#  9   ACTIVE                         6 non-null      int64
#  10
# INFECTED_NON_SPECIFIC_GENDER  6 non-null      int64
#  11  ACTIVE.1                       6 non-null      int64
# ...

# %%
region_df.describe()
# Out:
#         ID  ID_COUNTRY     \nINFECTED       \nDEAD       \nHEALED  \
# count  1.0         6.0       6.000000     6.000000       6.000000
# mean   1.0        15.0   42913.500000   532.833333   38858.500000
# std    NaN         0.0   44831.719194   438.663159   37319.717983
# min    1.0        15.0   10016.000000   172.000000    9531.000000
# 25%    1.0        15.0   14473.000000   236.000000   14074.750000
# 50%    1.0        15.0   28440.000000   397.500000   27755.000000
# 75%    1.0        15.0   45712.250000   628.000000   43911.000000
# max    1.0        15.0  129298.000000  1343.000000  109299.000000
#
#              ACTIVE  \nINFECTED_NON_SPECIFIC_GENDER      ACTIVE.1
# count      6.000000                        6.000000      6.000000
# mean    3522.166667                    32536.666667   3522.166667
# std     7435.606375                    34795.600122   7435.606375
# min      127.000000                     7234.000000    127.000000
# ...

# %%
# Calculate Active Cases

region_df['ACTIVE'] = region_df['\nINFECTED'] - (region_df['\nHEALED'] + region_df['\nDEAD'])
covid_df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/indexes/base.py?line=3650'>3651</a> try:
# -> <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/indexes/base.py?line=3651'>3652</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/indexes/base.py?line=3652'>3653</a> except KeyError as err:
#
# File c:\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
# Calculate Active Cases

region_df['ACTIVE'] = region_df['\nINFECTED'] - (region_df['HEALED'] + region_df['\nDEAD'])
covid_df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/indexes/base.py?line=3650'>3651</a> try:
# -> <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/indexes/base.py?line=3651'>3652</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/indexes/base.py?line=3652'>3653</a> except KeyError as err:
#
# File c:\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
# Calculate Active Cases

region_df['ACTIVE'] = region_df['\nINFECTED'] - (region_df[' \nHEALED'] + region_df['\nDEAD'])
covid_df.tail()
# Out:
#     ID                 DATE  ISO_3  COUNTRY  ID_COUNTRY    STATE  ID_STATE  \
# 32  33  2/27/2020 - 2/2/2022   NGA  Nigéria          15   Rivers       202
# 33  34  2/27/2020 - 2/2/2022   NGA  Nigéria          15   Sokoto       203
# 34  35  2/27/2020 - 2/2/2022   NGA  Nigéria          15   Taraba       204
# 35  36  2/27/2020 - 2/2/2022   NGA  Nigéria          15     Yobe       205
# 36  37  2/27/2020 - 2/2/2022   NGA  Nigéria          15  Zamfara       206
#
#     INFECTED  DEAD   HEALED  ACTIVE  INFECTED_NON_SPECIFIC_GENDER  \
# 32     16422   154    16148     120                         13726
# 33       811    28      783       0                           649
# 34      1469    34     1377      58                          1352
# 35       509     9      490      10                           430
# 36       375     9      366       0                           296
#
#                                 SOURCE
# 32  Nigeria Centre for Disease Control
# ...

# %%
regionwise = pd.pivot_table(region_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 regionwise = pd.pivot_table(region_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
#
# File c:\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/reshape/pivot.py?line=93'>94</a>     table = concat(pieces, keys=keys, axis=1)
#      <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/reshape/pivot.py?line=94'>95</a>     return table.__finalize__(data, method="pivot_table")
# ---> <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/reshape/pivot.py?line=96'>97</a> table = __internal_pivot_table(
# ...

# %%
regionwise = pd.pivot_table(region_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "REGION", aggfunc = max)

# %%
regionwise["Recovery Rate"] = regionwise[" \nHEALED"]*100/regionwise["\nINFECTED"]

# %%
regionwise["Mortality Rate"] = regionwise["DEAD"]*100/regionwise["INFECTED"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/indexes/base.py?line=3650'>3651</a> try:
# -> <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/indexes/base.py?line=3651'>3652</a>     return self._engine.get_loc(casted_key)
#    <a href='file:///c%3A/Python311/Lib/site-packages/pandas/core/indexes/base.py?line=3652'>3653</a> except KeyError as err:
#
# File c:\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
regionwise["Mortality Rate"] = regionwise["\nDEAD"]*100/regionwise["\nINFECTED"]

# %%
regionwise = regionwise.sort_values(by = "\nINFECTED", ascending = False)

# %%
regionwise.style.background_gradient(cmap = "cubehelix")
# Out:
# <style type="text/css">
# #T_354e5_row0_col0, #T_354e5_row0_col1, #T_354e5_row0_col2, #T_354e5_row3_col3, #T_354e5_row5_col4 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_354e5_row0_col3, #T_354e5_row1_col4, #T_354e5_row4_col0, #T_354e5_row5_col1, #T_354e5_row5_col2 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# #T_354e5_row0_col4 {
#   background-color: #160c1f;
#   color: #f1f1f1;
# }
# #T_354e5_row1_col0, #T_354e5_row2_col2 {
#   background-color: #16554b;
#   color: #f1f1f1;
# }
# #T_354e5_row1_col1 {
#   background-color: #286d3b;
#   color: #f1f1f1;
# }
# #T_354e5_row1_col2 {
#   background-color: #417731;
#   color: #f1f1f1;
# }
# #T_354e5_row1_col3 {
#   background-color: #c4dcf2;
#   color: #000000;
# }
# #T_354e5_row2_col0 {
#   background-color: #6f7b31;
#   color: #f1f1f1;
# }
# #T_354e5_row2_col1 {
#   background-color: #15444f;
#   color: #f1f1f1;
# }
# #T_354e5_row2_col3 {
#   background-color: #f2fbf6;
#   color: #000000;
# }
# ...

# %%
region_df_sorted = region_df.sort_values('REGION')
# Region Active Cases
region_active_cases = region_df.groupby(by = ['REGION']).max()[['ACTIVE']].reset_index()
fig = plt.figure(figsize=(16,9))
plt.title("Regions with Active Covid-19 Cases", size = 25)
ax = sns.barplot(data = region_active_cases.iloc[:10], y ="ACTIVE", x = "STATE", linewidth = 2, edgecolor = 'green')
plt.xlabel('REGION')
plt.ylabel('ACTIVE')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[42], line 6
#       4 fig = plt.figure(figsize=(16,9))
#       5 plt.title("Regions with Active Covid-19 Cases", size = 25)
# ----> 6 ax = sns.barplot(data = region_active_cases.iloc[:10], y ="ACTIVE", x = "STATE", linewidth = 2, edgecolor = 'green')
#       7 plt.xlabel('REGION')
#       8 plt.ylabel('ACTIVE')
#
# File c:\Python311\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    <a href='file:///c%3A/Python311/Lib/site-packages/seaborn/categorical.py?line=2751'>2752</a> if estimator is len:
#    <a href='file:///c%3A/Python311/Lib/site-packages/seaborn/categorical.py?line=2752'>2753</a>     estimator = "size"
# ...

# %%
region_df_sorted = region_df.sort_values('REGION')
# Region Active Cases
region_active_cases = region_df.groupby(by = ['REGION']).max()[['ACTIVE']].reset_index()
fig = plt.figure(figsize=(16,9))
plt.title("Regions with Active Covid-19 Cases", size = 25)
ax = sns.barplot(data = region_active_cases.iloc[:10], y ="ACTIVE", x = "REGION", linewidth = 2, edgecolor = 'green')
plt.xlabel('REGION')
plt.ylabel('ACTIVE')
plt.show()

# %%
# Regions With Highest Deaths

regional_deaths = region_df.groupby(by = 'REGION').max()[['\nDEAD']].sort_values(by = ['\nDEAD'], ascending = False).reset_index()

# %%
fig = plt.figure(figsize=(18,7))

# %%
plt.title('COVID-19 Related Deaths by Regions in Nigeria', size = 30)
# Out:
# Text(0.5, 1.0, 'COVID-19 Related Deaths by Regions in Nigeria')

# %%
region_df_sorted = region_df.sort_values('REGION')
# Region Active Cases
region_active_cases = region_df.groupby(by = ['REGION']).max()[['ACTIVE']].reset_index()
fig = plt.figure(figsize=(16,9))
plt.title("Regions with Active Covid-19 Cases", size = 25)
ax = sns.barplot(data = region_active_cases.iloc[:10], y ="ACTIVE", x = "REGION", linewidth = 2, edgecolor = 'green')
plt.xlabel('REGION')
plt.ylabel('ACTIVE')
plt.show()
