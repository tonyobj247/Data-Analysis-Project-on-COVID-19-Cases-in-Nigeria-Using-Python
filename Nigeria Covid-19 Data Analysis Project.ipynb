# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
covid_df = pd.read_excel('C:/Users/HP/Desktop/Paul Unilag Project/Nigeria Covid-19 Data Analysis Project/Nigeria Covid-19 Data Analysis Project_Statewise.xlsx')

# %%
covid_df.head(37)
# Out:
#     ID            DATE RANGE ISO_3  COUNTRY  ID_COUNTRY  \
# 0    1  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 1    2  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 2    3  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 3    4  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 4    5  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 5    6  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 6    7  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 7    8  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 8    9  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 9   10  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 10  11  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 11  12  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 12  13  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 13  14  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 14  15  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 15  16  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 16  17  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 17  18  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 18  19  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 19  20  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 20  21  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 21  22  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 22  23  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 23  24  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 24  25  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 25  26  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 26  27  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 27  28  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 28  29  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 29  30  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 30  31  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 31  32  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 32  33  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 33  34  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 34  35  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 35  36  2/27/2020 - 2/2/2022   NGA  Nigéria          15
# 36  37  2/27/2020 - 2/2/2022   NGA  Nigéria          15
#
#                         STATE  ID_STATE  \nINFECTED  \nDEAD   \nHEALED  \
# 0                        Abia       170        2152      34       2112
# 1                     Adamawa       171        1203      32       1103
# 2                   Akwa Ibom       172        4625      44       4494
# 3                     Anambra       173        2743      19       2678
# 4                      Bauchi       174        1936      24       1878
# 5                     Bayelsa       175        1305      28       1277
# 6                       Benue       176        2129      25       1764
# 7                       Borno       177        1629      44       1580
# 8                 Cross River       178         778      25        746
# 9                       Delta       179        5328     111       5170
# 10                     Ebonyi       180        2064      32       2004
# 11                        Edo       181        7672     320       7335
# 12                      Ekiti       182        1978      28       1919
# 13                      Enugu       183        2952      29       2910
# 14  Federal Capital Territory       184       28187     247      27405
# 15                      Gombe       185        3270      64       3103
# 16                        Imo       186        2442      58       2268
# 17                     Jigawa       187         664      18        642
# 18                     Kaduna       188       11185      89      11073
# 19                       Kano       189        4919     126       4726
# 20                    Katsina       190        2399      37       2339
# 21                      Kebbi       191         480      16        454
# 22                       Kogi       192           5       2          3
# 23                      Kwara       193        4541      64       4175
# 24                      Lagos       194       98366     769      80066
# 25                   Nasarawa       195        2703      39       2345
# 26                      Niger       196        1142      20        998
# 27                       Ogun       197        5798      82       5705
# 28                       Ondo       199        5143     107       4673
# 29                       Osun       198        3276      92       3127
# 30                        Oyo       200       10196     201       9634
# 31                    Plateau       201           0      75      10149
# 32                     Rivers       202       16422     154      16148
# 33                     Sokoto       203         811      28        783
# 34                     Taraba       204        1469      34       1377
# 35                       Yobe       205         509       9        490
# 36                    Zamfara       206         375       9        366
#
#     \nINFECTED_NON_SPECIFIC_GENDER                              SOURCE
# 0                             1254  Nigeria Centre for Disease Control
# 1                              955  Nigeria Centre for Disease Control
# 2                             4330  Nigeria Centre for Disease Control
# 3                             2468  Nigeria Centre for Disease Control
# 4                             1226  Nigeria Centre for Disease Control
# 5                              902  Nigeria Centre for Disease Control
# 6                             1645  Nigeria Centre for Disease Control
# 7                              884  Nigeria Centre for Disease Control
# 8                              691  Nigeria Centre for Disease Control
# 9                             3516  Nigeria Centre for Disease Control
# 10                            1015  Nigeria Centre for Disease Control
# 11                            5029  Nigeria Centre for Disease Control
# 12                            1650  Nigeria Centre for Disease Control
# 13                            1639  Nigeria Centre for Disease Control
# 14                           22277  Nigeria Centre for Disease Control
# 15                            2387  Nigeria Centre for Disease Control
# 16                            1853  Nigeria Centre for Disease Control
# 17                             339  Nigeria Centre for Disease Control
# 18                            8635  Nigeria Centre for Disease Control
# 19                            3178  Nigeria Centre for Disease Control
# 20                            1497  Nigeria Centre for Disease Control
# 21                             387  Nigeria Centre for Disease Control
# 22                               0  Nigeria Centre for Disease Control
# 23                            3491  Nigeria Centre for Disease Control
# 24                           77821  Nigeria Centre for Disease Control
# 25                            2227  Nigeria Centre for Disease Control
# 26                             869  Nigeria Centre for Disease Control
# 27                            3820  Nigeria Centre for Disease Control
# 28                            3489  Nigeria Centre for Disease Control
# 29                            2368  Nigeria Centre for Disease Control
# 30                            6787  Nigeria Centre for Disease Control
# 31                            6647  Nigeria Centre for Disease Control
# 32                           13726  Nigeria Centre for Disease Control
# 33                             649  Nigeria Centre for Disease Control
# 34                            1352  Nigeria Centre for Disease Control
# 35                             430  Nigeria Centre for Disease Control
# 36                             296  Nigeria Centre for Disease Control

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             37 non-null     int64
#  1   DATE RANGE                     37 non-null     object
#  2   ISO_3                          37 non-null     object
#  3   COUNTRY                        37 non-null     object
#  4   ID_COUNTRY                     37 non-null     int64
#  5   STATE                          37 non-null     object
#  6   ID_STATE                       37 non-null     int64
#  7
# INFECTED                      37 non-null     int64
#  8
# DEAD                          37 non-null     int64
#  9
# HEALED                       37 non-null     int64
#  10
# INFECTED_NON_SPECIFIC_GENDER  37 non-null     int64
#  11  SOURCE                         37 non-null     object
# dtypes: int64(7), object(5)
# memory usage: 3.6+ KB

# %%
covid_df.describe()
# Out:
#               ID  ID_COUNTRY    ID_STATE    \nINFECTED      \nDEAD  \
# count  37.000000        37.0   37.000000     37.000000   37.000000
# mean   19.000000        15.0  188.000000   6562.054054   84.729730
# std    10.824355         0.0   10.824355  16396.795180  134.458099
# min     1.000000        15.0  170.000000      0.000000    2.000000
# 25%    10.000000        15.0  179.000000   1203.000000   25.000000
# 50%    19.000000        15.0  188.000000   2399.000000   37.000000
# 75%    28.000000        15.0  197.000000   4919.000000   89.000000
# max    37.000000        15.0  206.000000  98366.000000  769.000000
#
#            \nHEALED  \nINFECTED_NON_SPECIFIC_GENDER
# count     37.000000                       37.000000
# mean    6189.702703                     5181.864865
# std    13538.481038                    12978.938739
# min        3.000000                        0.000000
# 25%     1277.000000                      902.000000
# 50%     2339.000000                     1650.000000
# 75%     4726.000000                     3516.000000
# max    80066.000000                    77821.000000

# %%
region_df = pd.read_excel('C:/Users/HP/Desktop/Paul Unilag Project/Nigeria Covid-19 Data Analysis Project/Nigeria Covid-19 Data Analysis Project_Regions.xlsx')

# %% [raw]
# region_df.head(7)

# %%
region_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             1 non-null      float64
#  1   DATE RANGE                     6 non-null      object
#  2   ISO_3                          6 non-null      object
#  3   COUNTRY                        6 non-null      object
#  4   ID_COUNTRY                     6 non-null      int64
#  5   REION                          6 non-null      object
#  6
# INFECTED                      6 non-null      int64
#  7
# DEAD                          6 non-null      int64
#  8
# HEALED                       6 non-null      int64
#  9
# INFECTED_NON_SPECIFIC_GENDER  6 non-null      int64
#  10  SOURCE                         6 non-null      object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 656.0+ bytes

# %%
region_df.describe()
# Out:
#         ID  ID_COUNTRY     \nINFECTED       \nDEAD       \nHEALED  \
# count  1.0         6.0       6.000000     6.000000       6.000000
# mean   1.0        15.0   42913.500000   532.833333   38858.500000
# std    NaN         0.0   44831.719194   438.663159   37319.717983
# min    1.0        15.0   10016.000000   172.000000    9531.000000
# 25%    1.0        15.0   14473.000000   236.000000   14074.750000
# 50%    1.0        15.0   28440.000000   397.500000   27755.000000
# 75%    1.0        15.0   45712.250000   628.000000   43911.000000
# max    1.0        15.0  129298.000000  1343.000000  109299.000000
#
#        \nINFECTED_NON_SPECIFIC_GENDER
# count                        6.000000
# mean                     32536.666667
# std                      34795.600122
# min                       7234.000000
# 25%                       9917.000000
# 50%                      21587.500000
# 75%                      34915.500000
# max                      99426.000000

# %%
covid_df.head()
# Out:
#    ID            DATE RANGE ISO_3  COUNTRY  ID_COUNTRY      STATE  ID_STATE  \
# 0   1  2/27/2020 - 2/2/2022   NGA  Nigéria          15       Abia       170
# 1   2  2/27/2020 - 2/2/2022   NGA  Nigéria          15    Adamawa       171
# 2   3  2/27/2020 - 2/2/2022   NGA  Nigéria          15  Akwa Ibom       172
# 3   4  2/27/2020 - 2/2/2022   NGA  Nigéria          15    Anambra       173
# 4   5  2/27/2020 - 2/2/2022   NGA  Nigéria          15     Bauchi       174
#
#    \nINFECTED  \nDEAD   \nHEALED  \nINFECTED_NON_SPECIFIC_GENDER  \
# 0        2152      34       2112                            1254
# 1        1203      32       1103                             955
# 2        4625      44       4494                            4330
# 3        2743      19       2678                            2468
# 4        1936      24       1878                            1226
#
#                                SOURCE
# 0  Nigeria Centre for Disease Control
# 1  Nigeria Centre for Disease Control
# 2  Nigeria Centre for Disease Control
# 3  Nigeria Centre for Disease Control
# 4  Nigeria Centre for Disease Control

# %%
region_df.head(8)
# Out:
#     ID            DATE RANGE ISO_3  COUNTRY  ID_COUNTRY             REION  \
# 0  1.0  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-WEST (SW)
# 1  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15   SOUTH-EAST (SE)
# 2  NaN  2/27/2020 - 2/2/2022   NGA  Nigéria          15  SOUTH-SOUTH (SS)
# 3  NaN  2/27/2020 - 2/2/2023   NGA  Nigéria          15   NORTH-WEST (NW)
# 4  NaN  2/27/2020 - 2/2/2024   NGA  Nigéria          15   NORTH-EAST (NE)
# 5  NaN  2/27/2020 - 2/2/2025   NGA  Nigéria          15       MIDDLE BELT
#
#    \nINFECTED  \nDEAD   \nHEALED  \nINFECTED_NON_SPECIFIC_GENDER  \
# 0      129298    1343     109299                           99426
# 1       12353     172      11972                            8229
# 2       36047     680      35127                           28194
# 3       20833     323      20383                           14981
# 4       10016     207       9531                            7234
# 5       48934     472      46839                           37156
#
#                                SOURCE
# 0  Nigeria Centre for Disease Control
# 1  Nigeria Centre for Disease Control
# 2  Nigeria Centre for Disease Control
# 3  Nigeria Centre for Disease Control
# 4  Nigeria Centre for Disease Control
# 5  Nigeria Centre for Disease Control

# %%
# Calculate Active Cases

covid_df['ACTIVE'] = covid_df['INFECTED'] - (covid_df['HEALED'] + covid_df['DEAD'])
covid_df.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 # Calculate Active Cases
# ----> 3 covid_df['ACTIVE'] = covid_df[INFECTED] - (covid_df['HEALED'] + covid_df['DEAD'])
#       4 covid_df.tail()
#
# NameError: name 'INFECTED' is not defined

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             37 non-null     int64
#  1   DATE RANGE                     37 non-null     object
#  2   ISO_3                          37 non-null     object
#  3   COUNTRY                        37 non-null     object
#  4   ID_COUNTRY                     37 non-null     int64
#  5   STATE                          37 non-null     object
#  6   ID_STATE                       37 non-null     int64
#  7
# INFECTED                      37 non-null     int64
#  8
# DEAD                          37 non-null     int64
#  9
# HEALED                       37 non-null     int64
#  10
# INFECTED_NON_SPECIFIC_GENDER  37 non-null     int64
#  11  SOURCE                         37 non-null     object
# dtypes: int64(7), object(5)
# memory usage: 3.6+ KB

# %%
print(covid_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             37 non-null     int64
#  1   DATE RANGE                     37 non-null     object
#  2   ISO_3                          37 non-null     object
#  3   COUNTRY                        37 non-null     object
#  4   ID_COUNTRY                     37 non-null     int64
#  5   STATE                          37 non-null     object
#  6   ID_STATE                       37 non-null     int64
#  7
# INFECTED                      37 non-null     int64
#  8
# DEAD                          37 non-null     int64
#  9
# HEALED                       37 non-null     int64
#  10
# INFECTED_NON_SPECIFIC_GENDER  37 non-null     int64
#  11  SOURCE                         37 non-null     object
# dtypes: int64(7), object(5)
# memory usage: 3.6+ KB
# None

# %%
# Calculate Active Cases

covid_df['ACTIVE'] = covid_df['\nINFECTED'] - (covid_df['\nHEALED	'] + covid_df['\nDEAD'])
covid_df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File C:\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '\nHEALED\t'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 3
#       1 # Calculate Active Cases
# ----> 3 covid_df['ACTIVE'] = covid_df['\nINFECTED'] - (covid_df['\nHEALED	'] + covid_df['\nDEAD'])
#       4 covid_df.tail()
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:3760, in __getitem__(self, key)
#    3758 if is_single_key:
#    3759     if self.columns.nlevels > 1:
# -> 3760         return self._getitem_multilevel(key)
#    3761     indexer = self.columns.get_loc(key)
#    3762     if is_integer(indexer):
#
# File C:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: '\nHEALED\t'

# %%
covid_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ID                             37 non-null     int64
#  1   DATE RANGE                     37 non-null     object
#  2   ISO_3                          37 non-null     object
#  3   COUNTRY                        37 non-null     object
#  4   ID_COUNTRY                     37 non-null     int64
#  5   STATE                          37 non-null     object
#  6   ID_STATE                       37 non-null     int64
#  7
# INFECTED                      37 non-null     int64
#  8
# DEAD                          37 non-null     int64
#  9
# HEALED                       37 non-null     int64
#  10
# INFECTED_NON_SPECIFIC_GENDER  37 non-null     int64
#  11  SOURCE                         37 non-null     object
# dtypes: int64(7), object(5)
# memory usage: 3.6+ KB

# %%
covid_df.head(8)
# Out:
#    ID            DATE RANGE ISO_3  COUNTRY  ID_COUNTRY      STATE  ID_STATE  \
# 0   1  2/27/2020 - 2/2/2022   NGA  Nigéria          15       Abia       170
# 1   2  2/27/2020 - 2/2/2022   NGA  Nigéria          15    Adamawa       171
# 2   3  2/27/2020 - 2/2/2022   NGA  Nigéria          15  Akwa Ibom       172
# 3   4  2/27/2020 - 2/2/2022   NGA  Nigéria          15    Anambra       173
# 4   5  2/27/2020 - 2/2/2022   NGA  Nigéria          15     Bauchi       174
# 5   6  2/27/2020 - 2/2/2022   NGA  Nigéria          15    Bayelsa       175
# 6   7  2/27/2020 - 2/2/2022   NGA  Nigéria          15      Benue       176
# 7   8  2/27/2020 - 2/2/2022   NGA  Nigéria          15      Borno       177
#
#    \nINFECTED  \nDEAD   \nHEALED  \nINFECTED_NON_SPECIFIC_GENDER  \
# 0        2152      34       2112                            1254
# 1        1203      32       1103                             955
# 2        4625      44       4494                            4330
# 3        2743      19       2678                            2468
# 4        1936      24       1878                            1226
# 5        1305      28       1277                             902
# 6        2129      25       1764                            1645
# 7        1629      44       1580                             884
#
#                                SOURCE
# 0  Nigeria Centre for Disease Control
# 1  Nigeria Centre for Disease Control
# 2  Nigeria Centre for Disease Control
# 3  Nigeria Centre for Disease Control
# 4  Nigeria Centre for Disease Control
# 5  Nigeria Centre for Disease Control
# 6  Nigeria Centre for Disease Control
# 7  Nigeria Centre for Disease Control

# %%
# Calculate Active Cases

covid_df['ACTIVE'] = covid_df['\nINFECTED'] - (covid_df['HEALED'] + covid_df['\nDEAD'])
covid_df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File C:\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'HEALED'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[40], line 3
#       1 # Calculate Active Cases
# ----> 3 covid_df['ACTIVE'] = covid_df['\nINFECTED'] - (covid_df['HEALED'] + covid_df['\nDEAD'])
#       4 covid_df.tail()
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:3760, in __getitem__(self, key)
#    3758 if is_single_key:
#    3759     if self.columns.nlevels > 1:
# -> 3760         return self._getitem_multilevel(key)
#    3761     indexer = self.columns.get_loc(key)
#    3762     if is_integer(indexer):
#
# File C:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'HEALED'

# %%
covid_df.head(10)
# Out:
#    ID            DATE RANGE ISO_3  COUNTRY  ID_COUNTRY        STATE  ID_STATE  \
# 0   1  2/27/2020 - 2/2/2022   NGA  Nigéria          15         Abia       170
# 1   2  2/27/2020 - 2/2/2022   NGA  Nigéria          15      Adamawa       171
# 2   3  2/27/2020 - 2/2/2022   NGA  Nigéria          15    Akwa Ibom       172
# 3   4  2/27/2020 - 2/2/2022   NGA  Nigéria          15      Anambra       173
# 4   5  2/27/2020 - 2/2/2022   NGA  Nigéria          15       Bauchi       174
# 5   6  2/27/2020 - 2/2/2022   NGA  Nigéria          15      Bayelsa       175
# 6   7  2/27/2020 - 2/2/2022   NGA  Nigéria          15        Benue       176
# 7   8  2/27/2020 - 2/2/2022   NGA  Nigéria          15        Borno       177
# 8   9  2/27/2020 - 2/2/2022   NGA  Nigéria          15  Cross River       178
# 9  10  2/27/2020 - 2/2/2022   NGA  Nigéria          15        Delta       179
#
#    \nINFECTED  \nDEAD   \nHEALED  \nINFECTED_NON_SPECIFIC_GENDER  \
# 0        2152      34       2112                            1254
# 1        1203      32       1103                             955
# 2        4625      44       4494                            4330
# 3        2743      19       2678                            2468
# 4        1936      24       1878                            1226
# 5        1305      28       1277                             902
# 6        2129      25       1764                            1645
# 7        1629      44       1580                             884
# 8         778      25        746                             691
# 9        5328     111       5170                            3516
#
#                                SOURCE
# 0  Nigeria Centre for Disease Control
# 1  Nigeria Centre for Disease Control
# 2  Nigeria Centre for Disease Control
# 3  Nigeria Centre for Disease Control
# 4  Nigeria Centre for Disease Control
# 5  Nigeria Centre for Disease Control
# 6  Nigeria Centre for Disease Control
# 7  Nigeria Centre for Disease Control
# 8  Nigeria Centre for Disease Control
# 9  Nigeria Centre for Disease Control

# %%
# Calculate Active Cases

covid_df['ACTIVE'] = covid_df['\nINFECTED'] - (covid_df['\nHEALED	'] + covid_df['\nDEAD'])
covid_df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File C:\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '\nHEALED\t'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[43], line 3
#       1 # Calculate Active Cases
# ----> 3 covid_df['ACTIVE'] = covid_df['\nINFECTED'] - (covid_df['\nHEALED	'] + covid_df['\nDEAD'])
#       4 covid_df.tail()
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:3760, in __getitem__(self, key)
#    3758 if is_single_key:
#    3759     if self.columns.nlevels > 1:
# -> 3760         return self._getitem_multilevel(key)
#    3761     indexer = self.columns.get_loc(key)
#    3762     if is_integer(indexer):
#
# File C:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: '\nHEALED\t'

# %%
# Calculate Active Cases

covid_df['ACTIVE'] = covid_df['\nINFECTED'] - (covid_df['\nHEALED'] + covid_df['\nDEAD'])
covid_df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File C:\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '\nHEALED'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 3
#       1 # Calculate Active Cases
# ----> 3 covid_df['ACTIVE'] = covid_df['\nINFECTED'] - (covid_df['\nHEALED'] + covid_df['\nDEAD'])
#       4 covid_df.tail()
#
# File C:\Python311\Lib\site-packages\pandas\core\frame.py:3760, in __getitem__(self, key)
#    3758 if is_single_key:
#    3759     if self.columns.nlevels > 1:
# -> 3760         return self._getitem_multilevel(key)
#    3761     indexer = self.columns.get_loc(key)
#    3762     if is_integer(indexer):
#
# File C:\Python311\Lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: '\nHEALED'

# %%
statewise = pd.pivot_table(covid_df, values = ["\nINFECTED", "HEALED", "DEAD"], index = "STATE", aggfunc = max)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 statewise = pd.pivot_table(covid_df, values = ["\nINFECTED", "\nHEALED", "DEAD"], index = "STATE", aggfunc = max)
#
# File C:\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File C:\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:143, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     141 for i in values:
#     142     if i not in data:
# --> 143         raise KeyError(i)
#     145 to_filter = []
#     146 for x in keys + values:
#
# KeyError: '\nHEALED'

# %%
covid_df.head()
# Out:
#    ID            DATE RANGE ISO_3  COUNTRY  ID_COUNTRY      STATE  ID_STATE  \
# 0   1  2/27/2020 - 2/2/2022   NGA  Nigéria          15       Abia       170
# 1   2  2/27/2020 - 2/2/2022   NGA  Nigéria          15    Adamawa       171
# 2   3  2/27/2020 - 2/2/2022   NGA  Nigéria          15  Akwa Ibom       172
# 3   4  2/27/2020 - 2/2/2022   NGA  Nigéria          15    Anambra       173
# 4   5  2/27/2020 - 2/2/2022   NGA  Nigéria          15     Bauchi       174
#
#    \nINFECTED  \nDEAD   \nHEALED  \nINFECTED_NON_SPECIFIC_GENDER  \
# 0        2152      34       2112                            1254
# 1        1203      32       1103                             955
# 2        4625      44       4494                            4330
# 3        2743      19       2678                            2468
# 4        1936      24       1878                            1226
#
#                                SOURCE
# 0  Nigeria Centre for Disease Control
# 1  Nigeria Centre for Disease Control
# 2  Nigeria Centre for Disease Control
# 3  Nigeria Centre for Disease Control
# 4  Nigeria Centre for Disease Control

# %%
statewise = pd.pivot_table(covid_df, values = ["\nINFECTED","\nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 statewise = pd.pivot_table(covid_df, values = ["\nINFECTED","\nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
#
# File C:\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File C:\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:143, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     141 for i in values:
#     142     if i not in data:
# --> 143         raise KeyError(i)
#     145 to_filter = []
#     146 for x in keys + values:
#
# KeyError: '\nHEALED'

# %%
print(covid_df.columns)
# Out:
# Index(['ID', 'DATE RANGE', 'ISO_3', 'COUNTRY', 'ID_COUNTRY', 'STATE',
#        'ID_STATE', '\nINFECTED', '\nDEAD', ' \nHEALED',
#        '\nINFECTED_NON_SPECIFIC_GENDER', 'SOURCE'],
#       dtype='object')

# %%
statewise = pd.pivot_table(covid_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)

# %%
statewise["Recovery Rate"] = statewise[" \nHEALED"]*100/statewise["\nINFECTED"]

# %%
statewise["Mortality Rate"] = statewise["\nDEAD"]*100/statewise["\nINFECTED"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 statewise["Mortality Rate"] = statewise["\nDEAD"]*100/statewise["\nINFECTED"]
#
# NameError: name 'statewise' is not defined

# %%
statewise = statewise.sort_values(by = "\nINFECTED", ascending = False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 statewise = statewise.sort_values(by = "\nINFECTED", ascending = False)
#
# NameError: name 'statewise' is not defined

# %%
statewise = pd.pivot_table(covid_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 statewise = pd.pivot_table(covid_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
statewise = pd.pivot_table(covid_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 statewise = pd.pivot_table(covid_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
#
# NameError: name 'covid_df' is not defined

# %%
statewise["Recovery Rate"] = statewise[" \nHEALED"]*100/statewise["\nINFECTED"]

# %%
statewise["Mortality Rate"] = statewise["\nDEAD"]*100/statewise["\nINFECTED"]

# %%
statewise = statewise.sort_values(by = "\nINFECTED", ascending = False)

# %%
statewise.style.background_gradient(cmap = "cubehelix")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 statewise.style.background_gradient(cmap = "cubehelix")
#
# NameError: name 'statewise' is not defined

# %%
statewise = pd.pivot_table(covid_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 statewise = pd.pivot_table(covid_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
#
# NameError: name 'covid_df' is not defined

# %%
covid_df = pd.read_excel('C:/Users/HP/Desktop/Paul Unilag Project/Nigeria Covid-19 Data Analysis Project/Nigeria Covid-19 Data Analysis Project_Statewise.xlsx')

# %%
statewise = pd.pivot_table(covid_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 statewise = pd.pivot_table(covid_df, values = ["\nINFECTED"," \nHEALED", "\nDEAD"], index = "STATE", aggfunc = max)
#
# File C:\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:97, in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#      94     table = concat(pieces, keys=keys, axis=1)
#      95     return table.__finalize__(data, method="pivot_table")
# ---> 97 table = __internal_pivot_table(
#      98     data,
#      99     values,
#     100     index,
#     101     columns,
#     102     aggfunc,
#     103     fill_value,
#     104     margins,
#     105     dropna,
#     106     margins_name,
#     107     observed,
#     108     sort,
#     109 )
#     110 return table.__finalize__(data, method="pivot_table")
#
# File C:\Python311\Lib\site-packages\pandas\core\reshape\pivot.py:143, in __internal_pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#     141 for i in values:
#     142     if i not in data:
# --> 143         raise KeyError(i)
#     145 to_filter = []
#     146 for x in keys + values:
#
# KeyError: '\nINFECTED'
